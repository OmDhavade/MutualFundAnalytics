# %% [markdown]
# # Mutual Fund Performance Analytics
#
# ## Objective
#
# This notebook computes key performance metrics for mutual funds, including:
#
# - Daily Returns
# - CAGR (1 Year, 3 Year, 5 Year)
# - Sharpe Ratio
# - Sortino Ratio
# - Alpha & Beta
# - Maximum Drawdown
# - Fund Scorecard
# - Benchmark Comparison
#
# Author: Om Dhavade

# %% [markdown]
# ---
# # Section 1 : Import Libraries
# ---

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from scipy.stats import linregress

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---
# # Section 2 : Load Data
# ---

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\OM DHAVADE\OneDrive\Desktop\MutualFundAnalytics\notebooks

# %%
import os

print(os.listdir(".."))
# Out:
# ['.git', '.ipynb_checkpoints', 'charts', 'clean_investor_transactions.py', 'clean_nav_history.py', 'clean_scheme_performance.py', 'dashboard', 'data', 'data_ingestion.py', 'explore_fund_master.py', 'live_nav_fetch.py', 'load_to_sqlite.py', 'mutualfund_analytics.db', 'nav_history_cleaned.csv', 'notebooks', 'reports', 'requirements.txt', 'sql', 'verify_row_counts.py']

# %%
print(os.listdir("../data"))
# Out:
# ['processed', 'raw']

# %%
print(os.listdir("../data/raw"))
# Out:
# ['01_fund_master.csv', '02_nav_history.csv', '03_aum_by_fund_house.csv', '04_monthly_sip_inflows.csv', '05_category_inflows.csv', '06_industry_folio_count.csv', '07_scheme_performance.csv', '08_investor_transactions.csv', '09_portfolio_holdings.csv', '10_benchmark_indices.csv', 'live_nav.csv', 'nav_data']

# %%
# Load datasets
fund_master = pd.read_csv("../data/raw/01_fund_master.csv")
nav_history = pd.read_csv("../data/raw/02_nav_history.csv")

# %%
fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# 0               1.54            1.0             500                1000
# 1               0.66            1.0             500                1000
# 2               1.43            1.0             500                1000
# 3               0.72            1.0             500                1000
# 4               0.77            0.0             500                1000
#
#     fund_manager risk_category sebi_category_code
# 0  Sohini Andani      Moderate               EC01
# 1  Sohini Andani      Moderate               EC01
# 2  R. Srinivasan     Very High               EC03
# 3  R. Srinivasan     Very High               EC03
# 4   Dinesh Ahuja           Low               DC02

# %%
nav_history.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
print("Fund Master Shape :", fund_master.shape)
print("NAV History Shape :", nav_history.shape)
# Out:
# Fund Master Shape : (40, 15)
# NAV History Shape : (46000, 3)

# %%
print(fund_master.columns)
print(nav_history.columns)
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='object')
# Index(['amfi_code', 'date', 'nav'], dtype='object')

# %%
fund_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     object
#  2   scheme_name         40 non-null     object
#  3   category            40 non-null     object
#  4   sub_category        40 non-null     object
#  5   plan                40 non-null     object
#  6   launch_date         40 non-null     object
#  7   benchmark           40 non-null     object
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     object
#  13  risk_category       40 non-null     object
#  14  sebi_category_code  40 non-null     object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 4.8+ KB

# %%
nav_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  object
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
fund_master.isnull().sum()
# Out:
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64

# %%
nav_history.isnull().sum()
# Out:
# amfi_code    0
# date         0
# nav          0
# dtype: int64

# %%
print("Fund Master Duplicates:", fund_master.duplicated().sum())
print("NAV History Duplicates:", nav_history.duplicated().sum())
# Out:
# Fund Master Duplicates: 0
# NAV History Duplicates: 0

# %% [markdown]
# ---
# # Section 3 : Data Preparation
# ---

# %%
# Convert to datetime
nav_history["date"] = pd.to_datetime(nav_history["date"])

# Verify
nav_history.info()

# Sort
nav_history = nav_history.sort_values(
    by=["amfi_code", "date"]
)

# Reset index
nav_history = nav_history.reset_index(drop=True)

# Check
nav_history.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  datetime64[ns]
#  2   nav        46000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.1 MB
#    amfi_code       date       nav
# 0     100016 2022-01-03  520.4608
# 1     100016 2022-01-04  515.0971
# 2     100016 2022-01-05  521.7239
# 3     100016 2022-01-06  515.7880
# 4     100016 2022-01-07  515.1639
# 5     100016 2022-01-10  510.7136
# 6     100016 2022-01-11  513.5542
# 7     100016 2022-01-12  512.3195
# 8     100016 2022-01-13  510.2445
# 9     100016 2022-01-14  514.3636

# %% [markdown]
# ---
# # Section 4 : Compute Daily Returns
# ---

# %%
# Compute daily returns for each mutual fund
nav_history["daily_return"] = (
    nav_history
        .groupby("amfi_code")["nav"]
        .pct_change()
)

# %%
nav_history.head(10)
# Out:
#    amfi_code       date       nav  daily_return
# 0     100016 2022-01-03  520.4608           NaN
# 1     100016 2022-01-04  515.0971     -0.010306
# 2     100016 2022-01-05  521.7239      0.012865
# 3     100016 2022-01-06  515.7880     -0.011377
# 4     100016 2022-01-07  515.1639     -0.001210
# 5     100016 2022-01-10  510.7136     -0.008639
# 6     100016 2022-01-11  513.5542      0.005562
# 7     100016 2022-01-12  512.3195     -0.002404
# 8     100016 2022-01-13  510.2445     -0.004050
# 9     100016 2022-01-14  514.3636      0.008073

# %%
nav_history["daily_return"].isnull().sum()
# Out:
# np.int64(40)

# %%
nav_history[nav_history["amfi_code"] == nav_history["amfi_code"].iloc[0]].head(10)
# Out:
#    amfi_code       date       nav  daily_return
# 0     100016 2022-01-03  520.4608           NaN
# 1     100016 2022-01-04  515.0971     -0.010306
# 2     100016 2022-01-05  521.7239      0.012865
# 3     100016 2022-01-06  515.7880     -0.011377
# 4     100016 2022-01-07  515.1639     -0.001210
# 5     100016 2022-01-10  510.7136     -0.008639
# 6     100016 2022-01-11  513.5542      0.005562
# 7     100016 2022-01-12  512.3195     -0.002404
# 8     100016 2022-01-13  510.2445     -0.004050
# 9     100016 2022-01-14  514.3636      0.008073

# %%
nav_history["daily_return"].describe()
# Out:
# count    45960.000000
# mean         0.000631
# std          0.010290
# min         -0.058102
# 25%         -0.005042
# 50%          0.000340
# 75%          0.006324
# max          0.064713
# Name: daily_return, dtype: float64

# %%
plt.figure(figsize=(10, 5))

plt.hist(
    nav_history["daily_return"].dropna(),
    bins=50
)

plt.title("Distribution of Daily Returns")
plt.xlabel("Daily Return")
plt.ylabel("Frequency")

plt.show()

# %%
nav_history["daily_return"].describe()
# Out:
# count    45960.000000
# mean         0.000631
# std          0.010290
# min         -0.058102
# 25%         -0.005042
# 50%          0.000340
# 75%          0.006324
# max          0.064713
# Name: daily_return, dtype: float64

# %%
print("Earliest Date :", nav_history["date"].min())
print("Latest Date   :", nav_history["date"].max())
# Out:
# Earliest Date : 2022-01-03 00:00:00
# Latest Date   : 2026-05-29 00:00:00

# %% [markdown]
# ---
# # Section 5 : CAGR (1 Year, 3 Year, 5 Year)
# ---

# %%
# Latest NAV for each fund
latest_nav = (
    nav_history
    .groupby("amfi_code")
    .last()
    .reset_index()
)

latest_nav.head()
# Out:
#    amfi_code       date       nav  daily_return
# 0     100016 2026-05-29  583.6113     -0.012410
# 1     100025 2026-05-29   31.8843     -0.000809
# 2     100033 2026-05-29  342.0072     -0.004798
# 3     101206 2026-05-29  773.2939     -0.008529
# 4     101207 2026-05-29   53.9836     -0.014623

# %%
latest_date = nav_history["date"].max()

print(latest_date)
# Out:
# 2026-05-29 00:00:00

# %%
one_year_date = latest_date - pd.DateOffset(years=1)
three_year_date = latest_date - pd.DateOffset(years=3)
five_year_date = latest_date - pd.DateOffset(years=5)

print("1 Year :", one_year_date)
print("3 Year :", three_year_date)
print("5 Year :", five_year_date)
# Out:
# 1 Year : 2025-05-29 00:00:00
# 3 Year : 2023-05-29 00:00:00
# 5 Year : 2021-05-29 00:00:00

# %%
nav_history[nav_history["date"] == one_year_date]
# Out:
#        amfi_code       date        nav  daily_return
# 888       100016 2025-05-29   596.8877     -0.002982
# 2038      100025 2025-05-29    30.7452      0.000700
# 3188      100033 2025-05-29   223.1951      0.006397
# 4338      101206 2025-05-29   522.7639     -0.007186
# 5488      101207 2025-05-29    71.0180      0.002711
# 6638      101208 2025-05-29   382.4272      0.000249
# 7788      102885 2025-05-29   156.2127      0.014817
# 8938      102886 2025-05-29   150.9137     -0.022312
# 10088     102887 2025-05-29   333.6461      0.003000
# 11238     118632 2025-05-29    82.5157     -0.008280
# 12388     118633 2025-05-29    72.9656      0.007868
# 13538     118634 2025-05-29   116.2826      0.005451
# 14688     118635 2025-05-29   266.7501      0.001734
# 15838     118636 2025-05-29    34.2441      0.000318
# 16988     119092 2025-05-29    50.0336     -0.009879
# 18138     119093 2025-05-29    48.7784      0.009228
# 19288     119094 2025-05-29   166.7400      0.001925
# 20438     119095 2025-05-29    98.1286     -0.002853
# 21588     119120 2025-05-29    51.3673     -0.001505
# 22738     119551 2025-05-29    93.0716      0.005741
# 23888     119552 2025-05-29   130.2974      0.000291
# 25038     119598 2025-05-29   169.1715      0.015048
# 26188     119599 2025-05-29    92.5730     -0.031128
# 27338     120503 2025-05-29   108.9046     -0.004295
# 28488     120504 2025-05-29   133.6683     -0.008317
# 29638     120505 2025-05-29   365.5455      0.015190
# 30788     120506 2025-05-29   285.1667      0.007557
# 31938     120507 2025-05-29   361.7349      0.000339
# 33088     120841 2025-05-29   412.6489     -0.004856
# 34238     120842 2025-05-29    67.4648      0.011368
# 35388     120843 2025-05-29   128.8832     -0.002609
# 36538     120844 2025-05-29  3984.8178      0.000895
# 37688     125497 2025-05-29   936.4319      0.000006
# 38838     125498 2025-05-29   163.1634      0.009940
# 39988     148567 2025-05-29   191.3173      0.024721
# 41138     148568 2025-05-29   179.7953      0.004632
# 42288     148569 2025-05-29    69.9408      0.001132
# 43438     149322 2025-05-29   513.2749     -0.000002
# 44588     149323 2025-05-29   201.9778      0.020053
# 45738     149324 2025-05-29   169.4037     -0.021366

# %%
def get_nav_on_or_before(df, target_date):
    """
    Returns the latest available NAV on or before the target date
    for each mutual fund.
    """

    return (
        df[df["date"] <= target_date]
        .groupby("amfi_code")
        .last()
        .reset_index()[["amfi_code", "nav"]]
    )

# %%
one_year_nav = get_nav_on_or_before(nav_history, one_year_date)

one_year_nav.head()
# Out:
#    amfi_code       nav
# 0     100016  596.8877
# 1     100025   30.7452
# 2     100033  223.1951
# 3     101206  522.7639
# 4     101207   71.0180

# %%
five_year_nav = get_nav_on_or_before(nav_history, five_year_date)

five_year_nav.head()
# Out:
# Empty DataFrame
# Columns: [amfi_code, nav]
# Index: []

# %%
three_year_nav = get_nav_on_or_before(
    nav_history,
    three_year_date
)

three_year_nav.head()
# Out:
#    amfi_code       nav
# 0     100016  561.5519
# 1     100025   28.4135
# 2     100033  147.2155
# 3     101206  360.4971
# 4     101207   61.3081

# %%
five_year_nav = get_nav_on_or_before(
    nav_history,
    five_year_date
)

five_year_nav.head()
# Out:
# Empty DataFrame
# Columns: [amfi_code, nav]
# Index: []

# %%
print("1 Year Funds :", len(one_year_nav))
print("3 Year Funds :", len(three_year_nav))
print("5 Year Funds :", len(five_year_nav))
# Out:
# 1 Year Funds : 40
# 3 Year Funds : 40
# 5 Year Funds : 0

# %%
# Rename NAV columns
latest_nav = latest_nav.rename(columns={"nav": "latest_nav"})
one_year_nav = one_year_nav.rename(columns={"nav": "nav_1yr"})
three_year_nav = three_year_nav.rename(columns={"nav": "nav_3yr"})

# %%
cagr_df = latest_nav.merge(
    one_year_nav,
    on="amfi_code",
    how="left"
)

cagr_df = cagr_df.merge(
    three_year_nav,
    on="amfi_code",
    how="left"
)

cagr_df.head()
# Out:
#    amfi_code       date  latest_nav  daily_return   nav_1yr   nav_3yr
# 0     100016 2026-05-29    583.6113     -0.012410  596.8877  561.5519
# 1     100025 2026-05-29     31.8843     -0.000809   30.7452   28.4135
# 2     100033 2026-05-29    342.0072     -0.004798  223.1951  147.2155
# 3     101206 2026-05-29    773.2939     -0.008529  522.7639  360.4971
# 4     101207 2026-05-29     53.9836     -0.014623   71.0180   61.3081

# %%
# CAGR for 1 year
cagr_df["cagr_1yr"] = (
    (cagr_df["latest_nav"] / cagr_df["nav_1yr"]) ** (1 / 1)
) - 1

# CAGR for 3 years
cagr_df["cagr_3yr"] = (
    (cagr_df["latest_nav"] / cagr_df["nav_3yr"]) ** (1 / 3)
) - 1

# %%
# Handle the 5-Year CAGR
cagr_df["cagr_5yr"] = np.nan

# %%
cagr_df["cagr_1yr"] = cagr_df["cagr_1yr"] * 100
cagr_df["cagr_3yr"] = cagr_df["cagr_3yr"] * 100

# %%
cagr_df[
    [
        "amfi_code",
        "cagr_1yr",
        "cagr_3yr",
        "cagr_5yr"
    ]
].head()
# Out:
#    amfi_code   cagr_1yr   cagr_3yr  cagr_5yr
# 0     100016  -2.224271   1.292649       NaN
# 1     100025   3.704969   3.916390       NaN
# 2     100033  53.232396  32.442459       NaN
# 3     101206  47.924120  28.967695       NaN
# 4     101207 -23.986032  -4.152381       NaN

# %%
# Merge CAGR table with fund details
cagr_df = cagr_df.merge(
    fund_master[
        [
            "amfi_code",
            "scheme_name",
            "fund_house",
            "category"
        ]
    ],
    on="amfi_code",
    how="left"
)

# %%
cagr_df = cagr_df[
    [
        "amfi_code",
        "scheme_name",
        "fund_house",
        "category",
        "cagr_1yr",
        "cagr_3yr",
        "cagr_5yr"
    ]
]

# %%
cagr_df["cagr_1yr"] = cagr_df["cagr_1yr"].round(2)
cagr_df["cagr_3yr"] = cagr_df["cagr_3yr"].round(2)

# %%
cagr_df.head()
# Out:
#    amfi_code                                        scheme_name  \
# 0     100016          HDFC Top 100 Fund - Regular Plan - Growth
# 1     100025       HDFC Short Term Debt Fund - Regular - Growth
# 2     100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 3     101206      ABSL Frontline Equity Fund - Regular - Growth
# 4     101207             ABSL Small Cap Fund - Regular - Growth
#
#                  fund_house category  cagr_1yr  cagr_3yr  cagr_5yr
# 0          HDFC Mutual Fund   Equity     -2.22      1.29       NaN
# 1          HDFC Mutual Fund     Debt      3.70      3.92       NaN
# 2          HDFC Mutual Fund   Equity     53.23     32.44       NaN
# 3  Aditya Birla Sun Life MF   Equity     47.92     28.97       NaN
# 4  Aditya Birla Sun Life MF   Equity    -23.99     -4.15       NaN

# %%
cagr_df = cagr_df.sort_values(
    by="cagr_3yr",
    ascending=False
)

# %%
cagr_df.head(10)
# Out:
#     amfi_code                                        scheme_name  \
# 16     119094                Axis Midcap Fund - Regular - Growth
# 34     148567      Mirae Asset Large Cap Fund - Regular - Growth
# 24     120504          ICICI Pru Bluechip Fund - Direct - Growth
# 2      100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 25     120505           ICICI Pru Midcap Fund - Regular - Growth
# 19     119551          SBI Bluechip Fund - Regular Plan - Growth
# 30     120843             Kotak Flexicap Fund - Regular - Growth
# 36     148569      Mirae Asset Tax Saver Fund - Regular - Growth
# 3      101206      ABSL Frontline Equity Fund - Regular - Growth
# 39     149324              DSP Small Cap Fund - Regular - Growth
#
#                   fund_house category  cagr_1yr  cagr_3yr  cagr_5yr
# 16          Axis Mutual Fund   Equity     22.26     35.11       NaN
# 34            Mirae Asset MF   Equity     20.36     34.00       NaN
# 24       ICICI Prudential MF   Equity     13.06     32.49       NaN
# 2           HDFC Mutual Fund   Equity     53.23     32.44       NaN
# 25       ICICI Prudential MF   Equity     29.60     31.78       NaN
# 19           SBI Mutual Fund   Equity     60.44     30.46       NaN
# 30         Kotak Mahindra MF   Equity     26.66     29.58       NaN
# 36            Mirae Asset MF   Equity     39.75     29.18       NaN
# 3   Aditya Birla Sun Life MF   Equity     47.92     28.97       NaN
# 39           DSP Mutual Fund   Equity     65.14     27.00       NaN

# %%
import os

os.makedirs("../outputs", exist_ok=True)

# %%
cagr_df.to_csv(
    "../outputs/cagr_comparison.csv",
    index=False
)

# %% [markdown]
# ---
# # Section 6 : Sharpe Ratio
# ---

# %%
# Annual risk-free rate (6.5%)
risk_free_rate = 0.065

# Convert to daily risk-free rate
daily_rf = risk_free_rate / 252

print("Annual RF :", risk_free_rate)
print("Daily RF  :", daily_rf)
# Out:
# Annual RF : 0.065
# Daily RF  : 0.00025793650793650796

# %%
mean_returns = (
    nav_history
    .groupby("amfi_code")["daily_return"]
    .mean()
)

mean_returns.head()
# Out:
# amfi_code
# 100016    0.000142
# 100025    0.000170
# 100033    0.001080
# 101206    0.000852
# 101207    0.000424
# Name: daily_return, dtype: float64

# %%
std_returns = (
    nav_history
    .groupby("amfi_code")["daily_return"]
    .std()
)

std_returns.head()
# Out:
# amfi_code
# 100016    0.009164
# 100025    0.002460
# 100033    0.011929
# 101206    0.009177
# 101207    0.016251
# Name: daily_return, dtype: float64

# %%
sharpe_df = pd.DataFrame({
    "mean_return": mean_returns,
    "std_return": std_returns
}).reset_index()

sharpe_df.head()
# Out:
#    amfi_code  mean_return  std_return
# 0     100016     0.000142    0.009164
# 1     100025     0.000170    0.002460
# 2     100033     0.001080    0.011929
# 3     101206     0.000852    0.009177
# 4     101207     0.000424    0.016251

# %%
# Calculate Sharpe Ratio
sharpe_df["sharpe_ratio"] = (
    (sharpe_df["mean_return"] - daily_rf)
    / sharpe_df["std_return"]
) * np.sqrt(252)

# %%
sharpe_df["sharpe_ratio"] = sharpe_df["sharpe_ratio"].round(3)

# %%
sharpe_df = sharpe_df.merge(
    fund_master[
        [
            "amfi_code",
            "scheme_name",
            "fund_house",
            "category"
        ]
    ],
    on="amfi_code",
    how="left"
)

# %%
sharpe_df = sharpe_df[
    [
        "amfi_code",
        "scheme_name",
        "fund_house",
        "category",
        "mean_return",
        "std_return",
        "sharpe_ratio"
    ]
]

# %%
sharpe_df = sharpe_df.sort_values(
    by="sharpe_ratio",
    ascending=False
)

# %%
sharpe_df.head(10)
# Out:
#    amfi_code                                        scheme_name  \
# 0     148567      Mirae Asset Large Cap Fund - Regular - Growth
# 1     120843             Kotak Flexicap Fund - Regular - Growth
# 2     148569      Mirae Asset Tax Saver Fund - Regular - Growth
# 3     119551          SBI Bluechip Fund - Regular Plan - Growth
# 4     120505           ICICI Pru Midcap Fund - Regular - Growth
# 5     149323                 DSP Midcap Fund - Regular - Growth
# 6     100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 7     118632     Nippon India Large Cap Fund - Regular - Growth
# 8     101206      ABSL Frontline Equity Fund - Regular - Growth
# 9     120504          ICICI Pru Bluechip Fund - Direct - Growth
#
#                  fund_house category  mean_return  std_return  sharpe_ratio
# 0            Mirae Asset MF   Equity     0.001074    0.008941         1.448
# 1         Kotak Mahindra MF   Equity     0.001082    0.010008         1.307
# 2            Mirae Asset MF   Equity     0.001124    0.011134         1.235
# 3           SBI Mutual Fund   Equity     0.000917    0.008656         1.208
# 4       ICICI Prudential MF   Equity     0.001161    0.012152         1.180
# 5           DSP Mutual Fund   Equity     0.001055    0.011179         1.132
# 6          HDFC Mutual Fund   Equity     0.001080    0.011929         1.094
# 7           Nippon India MF   Equity     0.000865    0.008913         1.082
# 8  Aditya Birla Sun Life MF   Equity     0.000852    0.009177         1.027
# 9       ICICI Prudential MF   Equity     0.000843    0.009048         1.027

# %%
print(sharpe_df["sharpe_ratio"].describe())
# Out:
# count    40.000000
# mean      0.537200
# std       0.573738
# min      -0.816000
# 25%       0.064750
# 50%       0.647000
# 75%       1.005250
# max       1.448000
# Name: sharpe_ratio, dtype: float64

# %%
# Keep only downside returns
downside_returns = nav_history.copy()

downside_returns["downside_return"] = downside_returns[
    "daily_return"
].where(
    downside_returns["daily_return"] < 0
)

# %%
downside_std = (
    downside_returns
    .groupby("amfi_code")["downside_return"]
    .std()
)

# %%
sortino_df = pd.DataFrame({
    "mean_return": mean_returns,
    "downside_std": downside_std
}).reset_index()

sortino_df.head()
# Out:
#    amfi_code  mean_return  downside_std
# 0     100016     0.000142      0.005261
# 1     100025     0.000170      0.001481
# 2     100033     0.001080      0.007133
# 3     101206     0.000852      0.005238
# 4     101207     0.000424      0.009555

# %%
# Calculate Sortino Ratio
sortino_df["sortino_ratio"] = (
    (sortino_df["mean_return"] - daily_rf)
    / sortino_df["downside_std"]
) * np.sqrt(252)

# %%
sortino_df["sortino_ratio"] = sortino_df["sortino_ratio"].round(3)

# %%
sortino_df = sortino_df.merge(
    fund_master[
        [
            "amfi_code",
            "scheme_name",
            "fund_house",
            "category"
        ]
    ],
    on="amfi_code",
    how="left"
)

# %%
sortino_df = sortino_df[
    [
        "amfi_code",
        "scheme_name",
        "fund_house",
        "category",
        "mean_return",
        "downside_std",
        "sortino_ratio"
    ]
]

# %%
sortino_df = sortino_df.sort_values(
    by="sortino_ratio",
    ascending=False
)

# %%
sortino_df.head(10)
# Out:
#     amfi_code                                        scheme_name  \
# 34     148567      Mirae Asset Large Cap Fund - Regular - Growth
# 30     120843             Kotak Flexicap Fund - Regular - Growth
# 36     148569      Mirae Asset Tax Saver Fund - Regular - Growth
# 19     119551          SBI Bluechip Fund - Regular Plan - Growth
# 25     120505           ICICI Pru Midcap Fund - Regular - Growth
# 38     149323                 DSP Midcap Fund - Regular - Growth
# 9      118632     Nippon India Large Cap Fund - Regular - Growth
# 2      100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 24     120504          ICICI Pru Bluechip Fund - Direct - Growth
# 3      101206      ABSL Frontline Equity Fund - Regular - Growth
#
#                   fund_house category  mean_return  downside_std  \
# 34            Mirae Asset MF   Equity     0.001074      0.005428
# 30         Kotak Mahindra MF   Equity     0.001082      0.005531
# 36            Mirae Asset MF   Equity     0.001124      0.006404
# 19           SBI Mutual Fund   Equity     0.000917      0.004887
# 25       ICICI Prudential MF   Equity     0.001161      0.007067
# 38           DSP Mutual Fund   Equity     0.001055      0.006750
# 9            Nippon India MF   Equity     0.000865      0.005211
# 2           HDFC Mutual Fund   Equity     0.001080      0.007133
# 24       ICICI Prudential MF   Equity     0.000843      0.005145
# 3   Aditya Birla Sun Life MF   Equity     0.000852      0.005238
#
#     sortino_ratio
# 34          2.386
# 30          2.364
# 36          2.147
# 19          2.140
# 25          2.029
# 38          1.875
# 9           1.850
# 2           1.829
# 24          1.805
# 3           1.800

# %%
print(sortino_df["sortino_ratio"].describe())
# Out:
# count    40.000000
# mean      0.923375
# std       1.005401
# min      -1.681000
# 25%       0.107000
# 50%       1.117000
# 75%       1.728000
# max       2.386000
# Name: sortino_ratio, dtype: float64

# %% [markdown]
# # Alpha and Beta Analysis
